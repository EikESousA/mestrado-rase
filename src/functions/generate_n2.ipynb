# %%
template = """
A metodologia **RASE N2** transforma textos normativos em uma estrutura organizada, garantindo que cada parte do texto apareça apenas uma vez, respeitando a seguinte ordem:

---

### **1. Aplicabilidade (Opcional)**
- **Onde ou quando a regra se aplica.**
- **Deve ser extraída primeiro, antes de outros elementos.**
- **Extraído SOMENTE do TEXTO N1.**
- **NÃO pode conter verbos, ações ou condições.**
- **Se não houver aplicabilidade, retornar `""` (string vazia).**

### **2. Seleção (Opcional)**
- **Parte mais específica da aplicabilidade.**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade.**
- **Deve ser um subconjunto da aplicabilidade, sem repetir o requisito.**
- **NÃO pode conter verbos, ações ou condições.**
- **Se não houver seleção, retornar `""` (string vazia).**

### **3. Exceção (Opcional)**
- **Casos que NÃO precisam seguir a regra.**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção.**
- **Se um elemento for uma exceção, ele não pode estar em outro campo.**
- **Se não houver, retornar `""` (string vazia).**

### **4. Requisito (Obrigatório)**
- **O que deve ser feito (ação ou condição).**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção.**
- **NÃO pode conter informações da aplicabilidade, seleção ou exceção.**
- **O requisito deve começar com um verbo e expressar uma ação ou condição clara.**

---

## **Regras obrigatórias**
✅ **Os elementos devem ser extraídos APENAS do Texto N1.**
✅ **Cada parte do texto deve aparecer apenas uma vez, na ordem Aplicabilidade > Seleção > Exceção > Requisito.**
✅ **Se um elemento não existir, retornar `""` (string vazia).**
✅ **O requisito deve ser a ação ou condição principal e nunca pode ser colocado na seleção.**
✅ **A seleção deve ser um subconjunto da aplicabilidade e não pode conter ações.**
✅ **O requisito deve começar com um verbo e expressar uma ação clara.**

---

### **Exemplo 1**

#### **Entrada:**
**Texto Completo:**
"As áreas de qualquer espaço ou edificação de uso público ou coletivo devem ser servidas de uma ou mais rotas acessíveis."

**Texto N1:**
"As áreas de qualquer espaço ou edificação de uso público ou coletivo devem ser servidas de uma ou mais rotas acessíveis."

#### **Saída Correta:**
aplicabilidade: "As áreas de qualquer espaço ou edificação"
selecao: "uso público ou coletivo"
execcao: ""
requisito: "devem ser servidas de uma ou mais rotas acessíveis"

---

### **Exemplo 2**

#### **Entrada:**
**Texto Completo:**
"As áreas de qualquer espaço ou edificação de uso público ou coletivo devem ser servidas de uma ou mais rotas acessíveis. Áreas de uso restrito, conforme definido em 3.1.38, como casas de máquinas, barriletes, passagem de uso técnico e outros com funções similares, não necessitam atender às condições de acessibilidade desta Norma."

**Texto N1:**
"Áreas de uso restrito, conforme definido em 3.1.38, como casas de máquinas, barriletes, passagem de uso técnico e outros com funções similares, não necessitam atender às condições de acessibilidade desta Norma."

#### **Saída Correta:**
aplicabilidade: ""
selecao: ""
execcao: "Áreas de uso restrito, conforme definido em 3.1.38, como casas de máquinas, barriletes, passagem de uso técnico e outros com funções similares"
requisito: "não necessitam atender às condições de acessibilidade desta Norma"

---

### **Agora, processe o seguinte texto:**

**Texto N1:**
"{transform}"

#### **Resposta:**
aplicabilidade:
selecao:
execcao:
requisito:
"""

# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate



model = OllamaLLM(model="llama3.3")

prompt = ChatPromptTemplate.from_template(template)

chain = prompt | model
result = chain.invoke({
    "text": "Os acessos devem ser vinculados através de rota acessível à circulação principal e às circulações de emergência. Os acessos devem permanecer livres de quaisquer obstáculos de forma permanente.",
    "transform": "Os acessos devem permanecer livres de quaisquer obstáculos de forma permanente."
})

print(result)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[7], line 12
#       9 prompt = ChatPromptTemplate.from_template(template)
#      11 chain = prompt | model
# ---> 12 result = chain.invoke({
#      13     "text": "Os acessos devem ser vinculados através de rota acessível à circulação principal e às circulações de emergência. Os acessos devem permanecer livres de quaisquer obstáculos de forma permanente.",
#      14     "transform": "Os acessos devem permanecer livres de quaisquer obstáculos de forma permanente."
#      15 })
#      17 print(result)
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_core\language_models\llms.py:387, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     377 def invoke(
#     378     self,
#     379     input: LanguageModelInput,
#    (...)
#     383     **kwargs: Any,
#     384 ) -> str:
#     385     config = ensure_config(config)
#     386     return (
# --> 387         self.generate_prompt(
#     388             [self._convert_input(input)],
#     389             stop=stop,
#     390             callbacks=config.get("callbacks"),
#     391             tags=config.get("tags"),
#     392             metadata=config.get("metadata"),
#     393             run_name=config.get("run_name"),
#     394             run_id=config.pop("run_id", None),
#     395             **kwargs,
#     396         )
#     397         .generations[0][0]
#     398         .text
#     399     )
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_core\language_models\llms.py:760, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     752 def generate_prompt(
#     753     self,
#     754     prompts: list[PromptValue],
#    (...)
#     757     **kwargs: Any,
#     758 ) -> LLMResult:
#     759     prompt_strings = [p.to_string() for p in prompts]
# --> 760     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_core\language_models\llms.py:963, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     948 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     949     run_managers = [
#     950         callback_manager.on_llm_start(
#     951             self._serialized,
#    (...)
#     961         )
#     962     ]
# --> 963     output = self._generate_helper(
#     964         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     965     )
#     966     return output
#     967 if len(missing_prompts) > 0:
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_core\language_models\llms.py:784, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     774 def _generate_helper(
#     775     self,
#     776     prompts: list[str],
#    (...)
#     780     **kwargs: Any,
#     781 ) -> LLMResult:
#     782     try:
#     783         output = (
# --> 784             self._generate(
#     785                 prompts,
#     786                 stop=stop,
#     787                 # TODO: support multiple run managers
#     788                 run_manager=run_managers[0] if run_managers else None,
#     789                 **kwargs,
#     790             )
#     791             if new_arg_supported
#     792             else self._generate(prompts, stop=stop)
#     793         )
#     794     except BaseException as e:
#     795         for run_manager in run_managers:
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_ollama\llms.py:288, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     286 generations = []
#     287 for prompt in prompts:
# --> 288     final_chunk = self._stream_with_aggregation(
#     289         prompt,
#     290         stop=stop,
#     291         run_manager=run_manager,
#     292         verbose=self.verbose,
#     293         **kwargs,
#     294     )
#     295     generations.append([final_chunk])
#     296 return LLMResult(generations=generations)
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_ollama\llms.py:256, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     247 def _stream_with_aggregation(
#     248     self,
#     249     prompt: str,
#    (...)
#     253     **kwargs: Any,
#     254 ) -> GenerationChunk:
#     255     final_chunk = None
# --> 256     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     257         if not isinstance(stream_resp, str):
#     258             chunk = GenerationChunk(
#     259                 text=stream_resp["response"] if "response" in stream_resp else "",
#     260                 generation_info=(
#     261                     dict(stream_resp) if stream_resp.get("done") is True else None
#     262                 ),
#     263             )
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\langchain_ollama\llms.py:211, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     205 def _create_generate_stream(
#     206     self,
#     207     prompt: str,
#     208     stop: Optional[List[str]] = None,
#     209     **kwargs: Any,
#     210 ) -> Iterator[Union[Mapping[str, Any], str]]:
# --> 211     yield from self._client.generate(
#     212         **self._generate_params(prompt, stop=stop, **kwargs)
#     213     )
#
# File c:\Users\eikes\Documents\GitHub\mestrado-rase\.venv\Lib\site-packages\ollama\_client.py:173, in Client._request.<locals>.inner()
#     171 part = json.loads(line)
#     172 if err := part.get('error'):
# --> 173   raise ResponseError(err)
#     174 yield cls(**part)
#
# ResponseError: error reading llm response: read tcp 127.0.0.1:54130->127.0.0.1:54074: wsarecv: Foi forçado o cancelamento de uma conexão existente pelo host remoto. (status code: -1)
