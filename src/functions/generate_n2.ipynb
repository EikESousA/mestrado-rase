# %%
import json
import re
import time
from typing import Dict, Any, Literal, Tuple
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableSerializable
import unicodedata

# %%
Tipo = Literal["n1", "n2", "n3"]
Modelo = Literal["llama", "alpaca", "mistral", "dolphin"]

def generate_config(tipo: Tipo, modelo: Modelo) -> Tuple[str, str, str]:
    input_file = f"../databases/data_{tipo}.json"

    modelos = {
        "llama": {
            "output_file": f"../databases/generate_{tipo}_llama.json",
            "model": "llama3.3:latest"
        },
        "alpaca": {
            "output_file": f"../databases/generate_{tipo}_alpaca.json",
            "model": "splitpierre/bode-alpaca-pt-br:latest"
        },
        "mistral": {
            "output_file": f"../databases/generate_{tipo}_mistral.json",
            "model": "cnmoro/mistral_7b_portuguese:q2_K"
        },
        "dolphin": {
            "output_file": f"../databases/generate_{tipo}_dolphin.json",
            "model": "cnmoro/llama-3-8b-dolphin-portuguese-v0.3:4_k_m"
        }
    }

    output_file = modelos[modelo]["output_file"]
    model = modelos[modelo]["model"]

    return input_file, output_file, model

# %%
def normalize_field_name(field: str) -> str:
    # Remove acentos
    field = unicodedata.normalize("NFKD", field).encode("ASCII", "ignore").decode("ASCII")
    field = field.lower()

    # Mapeia variações para os nomes esperados
    if field in ["selecao", "selecao", "seleçao", "seleção"]:
        return "selecao"
    elif field in ["execao", "excecao", "exceção", "execcao", "exeçao", "exeção"]:
        return "execao"
    elif field == "aplicabilidade":
        return "aplicabilidade"
    elif field == "requisito":
        return "requisito"
    return field

# %%
def process_text(texto: str) -> Dict[str, str]:
    campos = ["aplicabilidade", "selecao", "execao", "requisito"]
    resultado = {campo: "" for campo in campos}

    padrao_campo = re.compile(rf"^(.+?):\s*(.*)$", re.IGNORECASE)
    padrao_checagem = re.compile(rf"^({'|'.join(campos)}):$", re.IGNORECASE)

    campo_atual = None
    linhas = texto.splitlines()

    for linha in linhas:
        linha = linha.strip()
        if not linha:
            continue

        match = padrao_campo.match(linha)
        if match:
            raw_field = match.group(1).strip()
            campo = normalize_field_name(raw_field)
            valor = match.group(2).strip()

            if campo not in resultado:
                continue  # ignora campos inesperados

            if padrao_checagem.match(valor.lower()):
                valor = ""

            resultado[campo] = valor
            campo_atual = campo if valor == "" else None
        elif campo_atual:
            if not padrao_campo.match(linha):
                resultado[campo_atual] += " " + linha.strip()

    resultado = {k: v.strip() for k, v in resultado.items()}
    return resultado

# %%
def generate_n2(input_path: str, output_path: str, template: str, model: str) -> None:
    try:
        with open(input_path, "r", encoding="utf-8") as file:
            data = json.load(file)
    except FileNotFoundError:
        print("Erro: Arquivo de entrada não encontrado.")
        return
    except json.JSONDecodeError:
        print("Erro: Falha ao decodificar JSON de entrada.")
        return

    llm: OllamaLLM = OllamaLLM(model=model)
    prompt: ChatPromptTemplate = ChatPromptTemplate.from_template(template)
    chain: RunnableSerializable[Dict[str, str], str] = prompt | llm

    result_data: Dict[str, Any] = {"count": 0, "datas": [], "time": 0.0}
    total_start_time: float = time.time()

    with open(output_path, "w", encoding="utf-8") as file:
        json.dump(result_data, file, ensure_ascii=False, indent=4)

    for count, item in enumerate(data["datas"], start=1):
        start_time: float = time.time()
        full_response: str = chain.invoke({"transform": item["transform"]})
        processed_result: Dict[str, str] = process_text(full_response)
        end_time: float = time.time()

        elapsed_time: float = end_time - start_time
        result_entry: Dict[str, Any] = {
            "transform": item["transform"],
            "text": item["text"],
            "result": processed_result,
            "full": full_response,
            "time": elapsed_time,
        }

        result_data["datas"].append(result_entry)
        result_data["count"] = count
        result_data["time"] = time.time() - total_start_time

        with open(output_path, "w", encoding="utf-8") as file:
            json.dump(result_data, file, ensure_ascii=False, indent=4)

        print(f"Processando {count}: {item['transform']}")
        print(f"Retorno do modelo:\n{processed_result}")
        print(f"Tempo gasto: {elapsed_time:.2f} segundos\n")

    print(f"Processamento concluído. Tempo total: {result_data['time']:.2f} segundos.")
    print(f"Resultado salvo em {output_path}")

# %%
template = """
A metodologia **RASE N2** transforma textos normativos em uma estrutura organizada, garantindo que cada parte do texto apareça apenas uma vez, respeitando a seguinte ordem:

---

### **1. Aplicabilidade (Opcional)**
- **Onde ou quando a regra se aplica.**
- **Deve ser extraída primeiro, antes de outros elementos.**
- **Extraído SOMENTE do TEXTO N1.**
- **NÃO pode conter verbos, ações ou condições.**
- **Se não houver aplicabilidade, retornar `""` (string vazia).**

### **2. Seleção (Opcional)**
- **Parte mais específica da aplicabilidade.**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade.**
- **Deve ser um subconjunto da aplicabilidade, sem repetir o requisito.**
- **NÃO pode conter verbos, ações ou condições.**
- **Se não houver seleção, retornar `""` (string vazia).**

### **3. Exceção (Opcional)**
- **Casos que NÃO precisam seguir a regra.**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção.**
- **Se um elemento for uma exceção, ele não pode estar em outro campo.**
- **Se não houver, retornar `""` (string vazia).**

### **4. Requisito (Obrigatório)**
- **O que deve ser feito (ação ou condição).**
- **Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção.**
- **NÃO pode conter informações da aplicabilidade, seleção ou exceção.**
- **O requisito deve começar com um verbo e expressar uma ação ou condição clara.**

---

## **Regras obrigatórias**
**Os elementos devem ser extraídos APENAS do Texto N1.**
**Cada parte do texto deve aparecer apenas uma vez, na ordem Aplicabilidade > Seleção > Exceção > Requisito.**
**Se um elemento não existir, retornar `""` (string vazia).**
**O requisito deve ser a ação ou condição principal e nunca pode ser colocado na seleção.**
**A seleção deve ser um subconjunto da aplicabilidade e não pode conter ações.**
**O requisito deve começar com um verbo e expressar uma ação clara.**
**Retorne somente as resposta.**

---

### **Agora, processe o seguinte texto:**

**Texto N1:**
"{transform}"

#### **Resposta:**
aplicabilidade:
selecao:
execao:
requisito:
"""

# %%
input_file, output_file, model = generate_config("n2", "dolphin")

# %%
generate_n2(input_file, output_file, template, model)
# Out:
# Processando 1: As áreas de qualquer espaço ou edificação de uso público ou coletivo devem ser servidas de uma ou mais rotas acessíveis.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. Extraído SOMENTE do TEXTO N1.', 'selecao': 'Parte mais específica da aplicabilidade. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade.', 'execao': 'Casos que NÃO precisam seguir a regra. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção.', 'requisito': 'O que deve ser feito (ação ou condição). Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. "devem ser servidos por uma ou mais rotas acessíveis."'}
# Tempo gasto: 1.90 segundos
#
# Processando 2: As edificações residenciais multifamiliares, condomínios e conjuntos habitacionais necessitam ser acessíveis em suas áreas de uso comum.
# Retorno do modelo:
# {'aplicabilidade': '- "Edificações residenciais multifamiliares, condomínios e conjuntos habitacionais" - "" - "" - “Necessitam ser acessíveis em suas áreas de uso comum”', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.77 segundos
#
# Processando 3: As unidades autônomas acessíveis devem estar conectadas às rotas acessíveis.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '"conectar"'}
# Tempo gasto: 0.46 segundos
#
# Processando 4: Áreas de uso restrito, conforme definido em 3.1.38, como casas de máquinas, barriletes, passagem de uso técnico e outros com funções similares, não necessitam atender às condições de acessibilidade desta Norma.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.74 segundos
#
# Processando 5: Nas edificações e equipamentos urbanos, todas as entradas, bem como as rotas de interligação às funções do edifício, devem ser acessíveis.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. Parte mais específica da aplicabilidade. Casos que NÃO precisam seguir a regra. O que deve ser feito (ação ou condição).', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.74 segundos
#
# Processando 6: Os acessos devem ser vinculados através de rota acessível à circulação principal e às circulações de emergência.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': 'Parte mais específica da aplicabilidade.', 'execao': 'Casos que NÃO precisam seguir a regra.', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.65 segundos
#
# Processando 7: Os acessos devem permanecer livres de quaisquer obstáculos de forma permanente.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '""', 'execao': '""', 'requisito': '"O que deve ser feito (ação ou condição)."'}
# Tempo gasto: 1.09 segundos
#
# Processando 8: A instalação do dispositivo acessível para controle de acesso deve prever manobra de cadeira de rodas, conforme o disposto em 4.3.2, 4.3.4 e 4.3.5.
# Retorno do modelo:
# {'aplicabilidade': '"A instalação do dispositivo acessível para controle de acesso deve prever"', 'selecao': '"manobra de cadeira de rodas, conforme o disposto em"', 'execao': '""', 'requisito': '"4.3.2, 4.3.4 e 4.3.5."'}
# Tempo gasto: 0.76 segundos
#
# Processando 9: E os eventuais comandos acionáveis por usuários devem estar posicionados à altura indicada em 4.6.9.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra.', 'requisito': '- O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.69 segundos
#
# Processando 10: Em edificações e equipamentos urbanos deve ser prevista a sinalização informativa e direcional da localização das entradas e saídas acessíveis, de acordo com o estabelecido na Seção 5.
# Retorno do modelo:
# {'aplicabilidade': '"Em edificações e equipamentos urbanos deve ser prevista a sinalização informativa e direcional da localização das entradas e saídas acessíveis."', 'selecao': '"de acordo com o estabelecido na Seção 5."', 'execao': '""', 'requisito': ''}
# Tempo gasto: 0.75 segundos
#
# Processando 11: A inclinação transversal de pisos internos não pode exceder 2%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '"não pode exceder 2%"'}
# Tempo gasto: 0.46 segundos
#
# Processando 12: A inclinação transversal de pisos externos não pode exceder 3%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 6.57 segundos
#
# Processando 13: Pisos internos e externos devem ter inclinação longitudinal inferior a 5%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.04 segundos
#
# Processando 14: Inclinações iguais ou superiores a 5% são consideradas rampas e, portanto, devem atender a 6.6.
# Retorno do modelo:
# {'aplicabilidade': 'Inclinações iguais ou superiores a 5%.', 'selecao': 'Rampas', 'execao': '""', 'requisito': 'devem atender a 6.6'}
# Tempo gasto: 0.47 segundos
#
# Processando 15: Em reformas, pode-se considerar o desnível máximo de 75 mm, tratado com inclinação máxima de 12,5 %, conforme Tabela 7, sem avançar nas áreas de circulação transversal, e protegido lateralmente com elemento construído ou vegetação.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.19 segundos
#
# Processando 16: As soleiras das portas ou vãos de passagem que apresentem desníveis de até no máximo um degrau devem ter parte de sua extensão substituída por rampa com largura mínima de 0,90 m e com inclinação em função do desnível apresentado e atendendo aos parâmetros estabelecidos nos itens 6.6.2.1 ou 6.6.2.7.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Parte mais específica da aplicabilidade. - Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. - Casos que NÃO precisam seguir a regra. - Se um elemento for uma exceção, ele não pode estar em outro campo.', 'selecao': '', 'execao': '', 'requisito': '- O que deve ser feito (ação ou condição).'}
# Tempo gasto: 1.16 segundos
#
# Processando 17: Parte do desnível deve ser vencida com rampa, e o restante da extensão [degrau] pode permanecer como degrau, desde que associado, no mínimo em um dos lados, a uma barra de apoio horizontal ou vertical, com comprimento mínimo de 0,30 m e com seu eixo posicionado a 0,75 m de altura do piso, sem avançar sobre a área de circulação pública.
# Retorno do modelo:
# {'aplicabilidade': 'onde ou quando a regra se aplica. Parte mais específica da aplicação. Casos que não precisam seguir a regra. O que deve ser feito.', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.72 segundos
#
# Processando 18: A superfície das tampas deve estar nivelada com o piso adjacente.
# Retorno do modelo:
# {'aplicabilidade': '"A superfície das tampas"', 'selecao': '"deve ser nivelado com o piso adjacente."', 'execao': '""', 'requisito': '"estar nivelado"'}
# Tempo gasto: 0.49 segundos
#
# Processando 19: Eventuais frestas devem possuir dimensão máxima de 15 mm.
# Retorno do modelo:
# {'aplicabilidade': 'Eventuais frestas', 'selecao': 'Dimensão máxima de 15 mm', 'execao': '""', 'requisito': 'Os espaços devem possuir dimensão máxima de 15 mm.'}
# Tempo gasto: 0.55 segundos
#
# Processando 20: A sinalização visual e tátil no piso deve atender ao disposto em 5.4.6 e em normas específicas.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '"Parte mais específica da aplicabilidade."', 'execao': '"Casos que NÃO precisam seguir a regra."', 'requisito': '"O que deve ser feito (ação ou condição)."'}
# Tempo gasto: 0.69 segundos
#
# Processando 21: Quando em ambientes fechados, as rotas de fuga devem ser sinalizadas conforme o disposto na Seção 5 e iluminadas com dispositivos de balizamento de acordo com o estabelecido na ABNT NBR 10898.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '"Em ambientes fechados, as rotas de fuga devem ser sinalizadas conforme estabelecido na Seção 5 e iluminadas com dispositivos de balizamento de acordo com o disposto na ABNT NBR 10898."'}
# Tempo gasto: 0.70 segundos
#
# Processando 22: Nas áreas de resgate, deve ser previsto no mínimo um M.R. a cada 500 pessoas de lotação, por pavimento, sendo no mínimo um por pavimento e um para cada escada e elevador de emergência.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.21 segundos
#
# Processando 23: Se a antecâmara das escadas e a dos elevadores de emergência forem comuns, o quantitativo de M.R. pode ser compartilhado.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.61 segundos
#
# Processando 24: Recomenda-se prever uma área de descanso, fora da faixa de circulação, a cada 50 m, para piso com até 3 % de inclinação.
# Retorno do modelo:
# {'aplicabilidade': 'Extraído APENAS do TEXTO N1.', 'selecao': '"""', 'execao': '"""""', 'requisito': '"Recomenda-se prever uma área de descanso, fora da faixa de circulação, a cada 50 m, para piso com até 3 % de inclinação."'}
# Tempo gasto: 3.55 segundos
#
# Processando 25: Recomenda-se prever uma área de descanso, fora da faixa de circulação, a cada 30 m, para piso de 3 % a 5 % de inclinação.
# Retorno do modelo:
# {'aplicabilidade': 'Recomenda-se prever uma área de descanso', 'selecao': 'fora da faixa de circulação, a cada 30 m', 'execao': 'para piso com inclinação de 3 % a 5 %', 'requisito': 'prever uma área de descanso'}
# Tempo gasto: 0.75 segundos
#
# Processando 26: Para inclinações superiores a 5 %, deve ser atendido o descrito em 6.6.
# Retorno do modelo:
# {'aplicabilidade': '"Para inclinações superiores a 5%"', 'selecao': '""', 'execao': '""', 'requisito': '"deve ser atendido o descrito em 6.6"'}
# Tempo gasto: 0.52 segundos
#
# Processando 27: As áreas de descanso devem estar dimensionadas para permitir a manobra de cadeiras de rodas.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. Extraído SOMENTE do TEXTO N1. Parte mais específica da aplicabilidade. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade. Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. NÃO pode conter verbos, ações ou condições. Casos que NÃO precisam seguir a regra. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção. Se um elemento for uma exceção, ele não pode estar em outro campo. O que deve ser feito (ação ou condição). Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. NÃO pode conter informações da aplicabilidade, seleção ou exceção. O requisito deve começar com um verbo e expressar uma ação clara.', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.48 segundos
#
# Processando 28: Nas áreas de descanso recomenda-se a instalação de bancos com encosto e braços.
# Retorno do modelo:
# {'aplicabilidade': 'Nas áreas de descanso', 'selecao': 'Instalar bancos com encosto e braços', 'execao': '"não"', 'requisito': 'Instale bancos com encosto e braços'}
# Tempo gasto: 0.53 segundos
#
# Processando 29: As rampas devem ter inclinações entre 5% (1:20) e 8,33% (1:12) e devem atender os desníveis máximos por segmento e número de segmentos deste item, exceto rampas citadas em 10.4 (plateia e palcos), 10.12 (piscinas) e 10.14 (praias).
# Retorno do modelo:
# {'aplicabilidade': 'A rampa deve ter inclinações entre 5% (1:20) e 8,33% (1:12).', 'selecao': 'devem atender os desníveis máximos por segmento.', 'execao': 'rampas citadas em 10.4 (plateia e palcos), 10.12 (piscinas) e 10.14 (praias).', 'requisito': 'devem atender ao máximo de desníveis por segmento e número de segmentos.'}
# Tempo gasto: 1.21 segundos
#
# Processando 30: Para inclinação entre 6,25 % e 8,33 %, é recomendado criar áreas de descanso (6.5.) nos patamares, a cada 50 m de percurso.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.60 segundos
#
# Processando 31: Rampas com declividade igual a 5% (1:20) devem ter desnível máximo de 1,50 m por segmento, sem limite de número de segmentos.
# Retorno do modelo:
# {'aplicabilidade': 'Rampas com declividade igual a 5% (1:20)', 'selecao': 'devem ter desnível máximo', 'execao': 'sem limite de número de segmentos', 'requisito': 'por segmento'}
# Tempo gasto: 0.54 segundos
#
# Processando 32: Rampas com declividade maior do que 5% (1:20) e até 6,25% (1:16) devem ter desnível máximo de 1,00 m por segmento, sem limite de número de segmentos.
# Retorno do modelo:
# {'aplicabilidade': 'Rampas com declividade maior do que 5% (1:20) e até 6,25% (1:16)', 'selecao': 'sem limites de número de segmentos', 'execao': '', 'requisito': 'deve ter desnível máximo de 1,00 m por segmento'}
# Tempo gasto: 0.72 segundos
#
# Processando 33: Rampas com declividade maior do que 6,25% (1:16) e até 8,33% (1:12) devem ter desnível máximo de 0,80 m por segmento, com no máximo 15 segmentos e ter áreas de descanso nos patamares a cada 50,00 m de percurso horizontal.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': 'Parte mais específica da aplicabilidade.', 'execao': 'Casos que NÃO precisam seguir a regra.', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.68 segundos
#
# Processando 34: Para rampas em curva, a inclinação máxima admissível é de 8,33 % (1:12) e o raio mínimo de 3,00 m, medido no perímetro interno à curva.
# Retorno do modelo:
# {'aplicabilidade': 'Para rampas em curva', 'selecao': '', 'execao': 'não aplicável', 'requisito': ''}
# Tempo gasto: 0.77 segundos
#
# Processando 35: A dimensão longitudinal mínima do patamar é de 1,20 m, e recomendável 1,50 m.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '"Parte mais específica da aplicabilidade"', 'execao': '"Casos que NÃO precisam seguir a regra."', 'requisito': '"O que deve ser feito (ação ou condição)."'}
# Tempo gasto: 0.69 segundos
#
# Processando 36: A largura para as rampas em rotas acessíveis deve ser no mínimo 1,20 m, e recomendável 1,50m.
# Retorno do modelo:
# {'aplicabilidade': 'A largura deve ser no mínimo 1,20m', 'selecao': 'para rampas em rotas acessíveis', 'execao': '', 'requisito': 'não é recomendável 1,50m'}
# Tempo gasto: 0.53 segundos
#
# Processando 37: Quando não houver paredes laterais, as rampas devem incorporar elementos de segurança, como guarda-corpo e corrimãos, guias de balizamento com altura mínima de 0,05 m, instalados ou construídos nos limites da largura da rampa, conforme Figura 72.
# Retorno do modelo:
# {'aplicabilidade': 'Quando não houver paredes laterais,', 'selecao': 'elementos de segurança como guarda-corpo e corrimãos, guias de balizamento com altura mínima de 0,05 m,', 'execao': 'nenhuma', 'requisito': 'incorporar'}
# Tempo gasto: 0.73 segundos
#
# Processando 38: A guia de balizamento pode ser de alvenaria ou outro material alternativo, com a mesma finalidade, com altura mínima de 5cm.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 3.80 segundos
#
# Processando 39: Quando houver porta nos patamares, sua área de varredura não pode interferir na dimensão mínima do patamar.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': 'Dimensão mínima do patamar não interfere na varredura.', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.56 segundos
#
# Processando 40: Nas escadas fixas e degraus em rotas acessíveis, não podem ser utilizados espelhos vazados.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.16 segundos
#
# Processando 41: Se houver bocel ou espelho inclinado, a projeção da aresta pode avançar no máximo 1,5 cm sobre o piso abaixo.
# Retorno do modelo:
# {'aplicabilidade': '"Se houver bocel ou espelho inclinado"', 'selecao': '""', 'execao': '""', 'requisito': '"a projeção da aresta pode avançar no máximo 1,5 cm sobre o piso abaixo."'}
# Tempo gasto: 0.62 segundos
#
# Processando 42: a) a equação (piso + 2*espelho) deve ser maior ou igual a 0,63 m e menor ou igual a 0,65 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.46 segundos
#
# Processando 43: b) a profundidade do piso deve ser maior ou igual a 0,28 m e menor ou igual a 0,32 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.14 segundos
#
# Processando 44: c) a altura do espelho deve ser maior ou igual a 0,16 m e menou ou igual a 0,18 m.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '""', 'execao': '""', 'requisito': '"a altura do espelho deve ser maior ou igual a 0,16 m e menor ou igual a 0,18 m."'}
# Tempo gasto: 0.64 segundos
#
# Processando 45: Em construções novas, o primeiro e o último degraus de um lance de escada devem distar no mínimo 0,30 m da área de circulação adjacente.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra. (sem valor)', 'requisito': '- O que deve ser feito (ação ou condição). - Comece com um verbo e expresse uma ação clara. - "Primeiro e último degraus de uma escada devem distar no mínimo 0,30 m da área de circulação adjacente."'}
# Tempo gasto: 1.23 segundos
#
# Processando 46: Devem estar sinalizados de acordo com o disposto na Seção 5.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra.', 'requisito': '- O que deve ser feito (ação ou condição). - Devem estar sinalizados de acordo com o disposto na Seção 5.'}
# Tempo gasto: 0.88 segundos
#
# Processando 47: Escadas com lances curvos ou mistos devem atender à ABNT NBR 9077.
# Retorno do modelo:
# {'aplicabilidade': 'Escalões com lances curvos ou mistos', 'selecao': 'deva', 'execao': '"ABNT NBR 9077"', 'requisito': 'atender'}
# Tempo gasto: 0.45 segundos
#
# Processando 48: É necessário que, à distância de 0,55 m da borda interna da escada, os pisos e espelhos sejam dimensionados conforme 6.8.2.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.69 segundos
#
# Processando 49: Entre os lances da escada devem ser previstos patamares com dimensão longitudinal mínima de 1,20 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '- Parte mais específica da aplicabilidade. - Se não houver seleção, retornar `""` (string vazia).', 'execao': '- Casos que NÃO precisam seguir a regra. - Se um elemento for uma exceção, ele não pode estar em outro campo. - Se não houver exceção, retornar `""` (string vazia).', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção. - O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 1.81 segundos
#
# Processando 50: Os patamares situados em mudanças de direção devem ter dimensões iguais à largura da escada.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraído primeiro, antes de outros elementos. - Extraído SOMENTE do TEXTO N1. - NÃO pode conter verbos, ações ou condições. - Se não houver aplicabilidade, retornar `""` (string vazia).', 'selecao': '- Parte mais específica da aplicabilidade. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade. - Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. - NÃO pode conter verbos, ações ou condições. - Se não houver seleção, retornar `""` (string vazia).', 'execao': '- Casos que NÃO precisam seguir a regra. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção. - Se um elemento for uma exceção, ele não pode estar em outro campo. - Se não houver, retornar `""` (string vazia).', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - NÃO pode conter informações da aplicabilidade, seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação ou condição clara.'}
# Tempo gasto: 3.30 segundos
#
# Processando 51: Quando houver porta nos patamares, sua área de varredura não pode interferir na dimensão mínima do patamar.
# Retorno do modelo:
# {'aplicabilidade': '"Quando houver porta nos patamares"', 'selecao': '""', 'execao': '""', 'requisito': '"Sua área de varredura não pode interferir na dimensão mínima do patamar."'}
# Tempo gasto: 0.56 segundos
#
# Processando 52: Os corrimãos podem ser acoplados aos guarda-corpos.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.67 segundos
#
# Processando 53: Os corrimãos devem ser construídos com materiais rígidos.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.07 segundos
#
# Processando 54: Os corrimãos devem ser sinalizados conforme a Seção 5.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.11 segundos
#
# Processando 55: Os corrimãos devem ser instalados em ambos os lados de rampas, a 0,92 m e a 0,70 m do piso, medidos da face superior até a superfície do piso da rampa e do patamar.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 1.21 segundos
#
# Processando 56: Os corrimãos devem ser instalados em ambos os lados de escadas, a 0,92 m e a 0,70 m do piso, medidos da face superior até o ponto central do piso do degrau.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': 'ambos os lados', 'execao': 'nenhum', 'requisito': 'instale corrimãos a 0,92 m e a 0,70 m do piso'}
# Tempo gasto: 0.53 segundos
#
# Processando 57: Quando se tratar de degrau isolado, basta uma barra de apoio horizontal ou vertical, com comprimento mínimo de 0,30 m e com seu eixo posicionado a 0,75 m de altura do piso.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.60 segundos
#
# Processando 58: As extremidades dos corrimãos devem ter acabamento recurvado, ser fixadas ou justapostas à parede ou piso, ou ainda ter desenho contínuo, sem protuberâncias.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '"As extremidades dos corrimãos devem ter acabamento recurvado, ser fixadas ou justapostas à parede ou piso, ou ainda ter desenho contínuo, sem protuberâncias."'}
# Tempo gasto: 1.00 segundos
#
# Processando 59: Em escadas ou rampas com largura igual ou superior a 2,40 m, é necessária a instalação de no mínimo um corrimão intermediário, garantindo faixa livre de circulação com largura mínima de 1,20 m.
# Retorno do modelo:
# {'aplicabilidade': '"Escadas ou rampas"', 'selecao': '"com largura igual ou superior a 2,40m"', 'execao': '"Nenhum"', 'requisito': '"Instalação de no mínimo um corrimão intermediário"'}
# Tempo gasto: 0.60 segundos
#
# Processando 60: Em escadas e degraus é permitida a instalação de apenas um corrimão duplo e com duas alturas, a 0,92 m e a 0,70 m do piso, respeitando a largura mínima de 1,20 m, em ambos os lados.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.94 segundos
#
# Processando 61: Os guarda-corpos devem atender às ABNT NBR 9077 e ABNT 14718.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.23 segundos
#
# Processando 62: Para transposição de obstáculos, objetos e elementos com no máximo 0,40 m de extensão, a largura mínima do corredor deve ser de 0,80 m.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. Deve ser extraída primeiro, antes de outros elementos. Extraído SOMENTE do TEXTO N1. Parte mais específica da aplicabilidade. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade. Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. NÃO pode conter verbos, ações ou condições. Casos que NÃO precisam seguir a regra. Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção. Se um elemento for uma exceção, ele não pode estar em outro campo.', 'selecao': '', 'execao': '', 'requisito': 'O que deve ser feito (ação ou condição). Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. NÃO pode conter informações da aplicabilidade, seleção ou exceção. O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 2.53 segundos
#
# Processando 63: Para transposição de obstáculos, objetos e elementos com extensão acima de 0,40 m, a largura mínima do corredor deve ser de 0,90 m.
# Retorno do modelo:
# {'aplicabilidade': '"Para transposição de obstáculos"', 'selecao': '""', 'execao': '""', 'requisito': '"a largura mínima do corredor deve ser 0,90 m"'}
# Tempo gasto: 0.51 segundos
#
# Processando 64: No deslocamento frontal, quando as portas abrirem no sentido do deslocamento do usuário, deve existir um espaço livre de 0,30 m entre a parede e a porta.
# Retorno do modelo:
# {'aplicabilidade': '"No deslocamento frontal"', 'selecao': '"quando as portas abrirem no sentido do deslocamento do usuário"', 'execao': '"deve existir um espaço livre de 0,30 m entre a parede e a porta"', 'requisito': ''}
# Tempo gasto: 0.63 segundos
#
# Processando 65: No deslocamento frontal, quando as portas abrirem no sentido oposto ao deslocamento do usuário, deve existir um espaço livre de 0,60 m, contíguo à maçaneta.
# Retorno do modelo:
# {'aplicabilidade': 'Deslocamento frontal', 'selecao': '', 'execao': '""', 'requisito': 'deve existir um espaço livre de 0,60 m contíguo à maçaneta'}
# Tempo gasto: 0.66 segundos
#
# Processando 66: Na impraticabilidade da existência destes espaços livres, deve-se garantir equipamento de automação da abertura e fechamento das portas através de botoeira ou sensor, conforme 6.11.2.9 e 6.11.2.10.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.49 segundos
#
# Processando 67: As portas, quando abertas, devem ter um vão livre, de no mínimo 0,80 m de largura e 2,10 m de altura.
# Retorno do modelo:
# {'aplicabilidade': '"As portas, quando abertas"', 'selecao': '"devem ter um vão livre"', 'execao': '', 'requisito': '"de no mínimo 0,80 m de largura e 2,10 m de altura"'}
# Tempo gasto: 0.66 segundos
#
# Processando 68: Em portas de duas ou mais folhas, pelo menos uma delas deve ter o vão livre de 0,80 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.74 segundos
#
# Processando 69: O mecanismo de acionamento das portas deve requerer força humana direta igual ou inferior a 36 N.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': 'Parte mais específica da aplicabilidade.', 'execao': '', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.54 segundos
#
# Processando 70: As portas de sanitários e vestiários devem ter, no lado oposto ao lado da abertura da porta, um puxador horizontal associado à maçaneta.
# Retorno do modelo:
# {'aplicabilidade': 'As portas dos sanitários e das casas de banho devem ter', 'selecao': 'no lado oposto ao lado da abertura da porta', 'execao': '', 'requisito': 'um puxador horizontal associado à maçaneta'}
# Tempo gasto: 0.61 segundos
#
# Processando 71: O puxador horizontal deve estar localizado a uma distância de 0,10 m do eixo da porta (dobradiça) e possuir comprimento mínimo de 0,40 m, com diâmetro variando de 35 mm a 25 mm, instalado a 0,90 m do piso.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': 'Parte mais específica da aplicabilidade.', 'execao': 'Casos que não precisam seguir a regra (não existem no texto fornecido).', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 6.19 segundos
#
# Processando 72: O dispositivo de travamento deve observar o descrito em 4.6.8.
# Retorno do modelo:
# {'aplicabilidade': 'Obrigatório', 'selecao': '""', 'execao': '""', 'requisito': '"O dispositivo de travamento deve observar o descrito em 4.6.8."'}
# Tempo gasto: 0.47 segundos
#
# Processando 73: Recomenda-se que as portas ou batentes de sanitários e vestiários tenham cor contrastante com a da parede e do piso.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '"Recomenda-se que as portas ou batentes de sanitários e vestiários tenham cor contrastante com a da parede e do piso."'}
# Tempo gasto: 0.55 segundos
#
# Processando 74: Quando as portas forem providas de dispositivos de acionamento pelo usuário, estes devem estar instalados fora da área de abertura da folha da porta e à altura de alcance entre 0,80 m e 1,00 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.88 segundos
#
# Processando 75: Em portas de correr, recomenda-se a instalação de trilhos na sua parte superior.
# Retorno do modelo:
# {'aplicabilidade': '"Em portas de corrida"', 'selecao': '"instalando trilhos em sua parte superior"', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.33 segundos
#
# Processando 76: Os trilhos ou as guias inferiores, se houver, devem estar nivelados com a superfície do piso.
# Retorno do modelo:
# {'aplicabilidade': 'Nível com o solo.', 'selecao': 'A superfície do piso.', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.27 segundos
#
# Processando 77: As frestas resultantes da guia inferior devem ter largura de no máximo 15 mm.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.12 segundos
#
# Processando 78: A sinalização vertical das vagas reservadas deve estar posicionada de maneira a não interferir com as áreas de acesso ao veículo, e na circulação dos pedestres.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraído primeiro, antes de outros elementos.', 'selecao': '- Parte mais específica da aplicabilidade. - Extraída apenas do TEXTO N1, após a remoção de aplicação. - Deve ser um subconjunto da aplicação, sem repetir o requisito.', 'execao': '- Casos que não precisam seguir a regra. - Extraído apenas do TEXTO N1, após a remoção de aplicabilidade e seleção. - Se um elemento for uma exceção, ele não pode estar em outro campo.', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído apenas do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - Não pode conter informações da aplicabilidade, seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação ou condição clara.'}
# Tempo gasto: 2.33 segundos
#
# Processando 79: A superfície de varredura do portão não pode invadir a faixa livre de circulação de pedestre.
# Retorno do modelo:
# {'aplicabilidade': 'A superfície da varredura do portão', 'selecao': 'faixa de circulação gratuita de pedestres', 'execao': 'circulação de pedestre', 'requisito': ''}
# Tempo gasto: 0.49 segundos
#
# Processando 80: A superfície de varredura do portão deve contar com sistema de sinalização conforme 5.6.4.2.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 3.75 segundos
#
# Processando 81: A largura para as rampas em rotas acessíveis deve ser no mínimo 1,20 m, e recomendável 1,50 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.19 segundos
#
# Processando 82: A guia de balizamento pode ser de alvenaria ou outro material alternativo, com a mesma finalidade, com altura mínima de 5 cm.
# Retorno do modelo:
# {'aplicabilidade': 'A guia de balizamento pode ser de alvenaria ou outro material alternativo', 'selecao': 'com a mesma finalidade', 'execao': '', 'requisito': 'com altura mínima de 5 cm'}
# Tempo gasto: 0.55 segundos
#
# Processando 83: A circulação vertical acessível deve atender no mínimo duas formas de deslocamento: escadas, rampas ou equipamentos eletromecânicos.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 1.18 segundos
#
# Processando 84: Desníveis superiores a 20 mm, devem ser considerados como degraus, conforme 6.7.
# Retorno do modelo:
# {'aplicabilidade': '- Desníveis - acima - 20 mm', 'selecao': '- como - degraus', 'execao': '- conforme - 6.7', 'requisito': '- devem ser considerados'}
# Tempo gasto: 0.58 segundos
#
# Processando 85: As rotas de fuga devem atender ao disposto na ABNT NBR 9077 e outras regulamentações locais contra incêndio e pânico.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.15 segundos
#
# Processando 86: As portas de corredores, acessos, áreas de resgate, escadas de emergência e descargas integrantes de rotas de fuga acessíveis devem ser dotadas de barras antipânico, conforme ABNT NBR 11785.
# Retorno do modelo:
# {'aplicabilidade': '"As portas de corredores, acessos, áreas de resgate, escadas de emergência e descargas integrantes de rotas de fuga acessíveis devem ser dotadas de barras antipânico"', 'selecao': '""', 'execao': '', 'requisito': '"ser dotado de barra antipânica"'}
# Tempo gasto: 0.86 segundos
#
# Processando 87: As escadas devem ter no mínimo um patamar a cada 3,20 m de desnível.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.74 segundos
#
# Processando 88: As escadas devem ter no mínimo um patamar sempre que houver mudança de direção.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.10 segundos
#
# Processando 89: Os corrimãos laterais devem ser contínuos, sem interrupção nos patamares das escadas e rampas.
# Retorno do modelo:
# {'aplicabilidade': '"Em todas as escadas e rampas."', 'selecao': '', 'execao': '"Se houver interrupções nos patamares das escadas e rampas."', 'requisito': '"Os corrimãos laterais devem ser contínuos."'}
# Tempo gasto: 0.65 segundos
#
# Processando 90: Os corrimãos laterais devem prolongar-se paralelamente ao patamar, pelo menos por 0,30 m nas extremidades, sem interferir com áreas de circulação ou prejudicar a vazão.
# Retorno do modelo:
# {'aplicabilidade': 'Os corrimãos laterais', 'selecao': 'paralelos ao patamar, pelo menos 0,30 m nas extremidades sem interferir com áreas de circulação ou prejudicar a vazão.', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.54 segundos
#
# Processando 91: Em edificações e equipamentos urbanos existentes, onde a adequação dos corredores seja impraticável, devem ser implantados bolsões de retorno com dimensões que permitam a manobra completa de uma cadeira de rodas (180°), sendo no mínimo um bolsão a cada 15,00 m.
# Retorno do modelo:
# {'aplicabilidade': '- "Em edificações e equipamentos urbanos existentes" - "onde a adequação dos corredores seja impraticável"', 'selecao': '- "devem ser implantados bolsões de retorno"', 'execao': '- "" - ""', 'requisito': '- “com dimensões que permitam a manobra completa de uma cadeira de rodas (180°), sendo no mínimo um bolsão a cada 15,00 m”'}
# Tempo gasto: 1.05 segundos
#
# Processando 92: Neste caso, a largura mínima de corredor deve ser de 0,90 m.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.49 segundos
#
# Processando 93: Toda rota acessível deve ser provida de iluminação natural ou artificial com nível mínimo de iluminância de 150 lux medidos a 1,00 m do chão.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.21 segundos
#
# Processando 94: São aceitos níveis inferiores de iluminância para ambientes específicos, como cinemas, teatros ou outros, conforme normas técnicas específicas.
# Retorno do modelo:
# {'aplicabilidade': '"São aceitos níveis inferiores de iluminância para ambientes específicos"', 'selecao': '""', 'execao': '""', 'requisito': '"como cinemas, teatros ou outros conforme normas técnicas específicas"'}
# Tempo gasto: 0.60 segundos
#
# Processando 95: Nestes casos a distância entre cada entrada acessível e as demais não pode ser superior a 50 m.
# Retorno do modelo:
# {'aplicabilidade': '"Nestes casos"', 'selecao': '""', 'execao': '""', 'requisito': '"não pode ser superior a 50 m"'}
# Tempo gasto: 0.40 segundos
#
# Processando 96: A entrada predial principal, ou a entrada de acesso do maior número de pessoas, tem a obrigatoriedade de atender a todas as condições de acessibilidade.
# Retorno do modelo:
# {'aplicabilidade': 'A entrada predial principal, ou a entrada de acesso do maior número de pessoas', 'selecao': '', 'execao': '', 'requisito': 'tem a obrigatória de atender todas as condições de acessibilidade.'}
# Tempo gasto: 0.55 segundos
#
# Processando 97: O percurso entre o estacionamento de veículos e os acessos deve compor uma rota acessível.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - NÃO pode conter informações da aplicabilidade, seleção ou exceção.'}
# Tempo gasto: 2.16 segundos
#
# Processando 98: Quando for instalada, deve ser prevista, junto a esta, outra entrada que garanta condições de acessibilidade.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 3.80 segundos
#
# Processando 99: Quando for instalada, as dimensões entre as pás devem ser compatíveis com as medidas de um M.R. e devem ainda ser dotadas de sistema de segurança para rebatimento das pás em caso de sinistro.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.51 segundos
#
# Processando 100: Desníveis superiores a 5 mm até 20 mm devem possuir inclinação máxima de 1:2 (50 %).
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.50 segundos
#
# Processando 101: Desníveis superiores a 20 mm, devem ser considerados como degraus, conforme 6.7.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': 'Desníveis superiores a 20 mm devem ser considerados como degraus.'}
# Tempo gasto: 0.29 segundos
#
# Processando 102: Nas áreas de circulação, quando o desnível for lateral, observar o descrito em 4.3.7.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica." - "Nas áreas de circulação"', 'selecao': '"Parte mais específica da aplicabilidade."', 'execao': '"Casos que NÃO precisam seguir a regra." - "Se um elemento for uma exceção, ele não pode estar em outro campo."', 'requisito': '"Ação ou condição principal que deve ser feita." - "Observar o descrito em 4.3.7"'}
# Tempo gasto: 1.14 segundos
#
# Processando 103: Em rotas acessíveis, as grelhas e juntas de dilatação devem estar fora do fluxo principal de circulação.
# Retorno do modelo:
# {'aplicabilidade': '"rotas acessíveis"', 'selecao': '"grevas e juntas de dilatação"', 'execao': '""', 'requisito': '"estar fora do fluxo principal de circulação"'}
# Tempo gasto: 0.49 segundos
#
# Processando 104: Quando não possível tecnicamente, os vãos devem ter dimensão máxima de 15 mm, devem ser instalados perpendicularmente ao fluxo principal.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra.', 'requisito': '- O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.82 segundos
#
# Processando 105: Formato quadriculado/circular, quando houver fluxos em mais de um sentido de circulação.
# Retorno do modelo:
# {'aplicabilidade': '"Formato quadriculado ou circular"', 'selecao': '""', 'execao': '""', 'requisito': '"em mais de um sentido de circulação"'}
# Tempo gasto: 0.44 segundos
#
# Processando 106: Quando existentes, devem ser firmemente fixados ao piso, embutidos ou sobrepostos e nivelados de maneira que eventual desnível não exceda 5 mm.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.78 segundos
#
# Processando 107: Quando as rotas de fuga incorporarem escadas de emergência ou elevadores de emergência, devem ser previstas áreas de resgate (6.4.5) com espaço reservado e demarcado para o posicionamento de pessoas em cadeiras de rodas (5.5.2.2), dimensionadas de acordo com o M.R.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.87 segundos
#
# Processando 108: A área de resgate deve estar localizada fora do fluxo principal de circulação.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.32 segundos
#
# Processando 109: A área de resgate deve garantir área mínima de circulação e manobra para rotação de 180°, conforme 4.3.3.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '', 'execao': '', 'requisito': '"A área de resgate deve garantir uma área mínima de circulação e manobra para rotação de 180°."'}
# Tempo gasto: 0.62 segundos
#
# Processando 110: A área de resgate, quando localizada em nichos, deve respeitar os parâmetros mínimos definidos em 4.3.6.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.26 segundos
#
# Processando 111: A área de resgate deve ser ventilada.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '', 'execao': '', 'requisito': '"A área de resgate deve ser ventilada."'}
# Tempo gasto: 0.37 segundos
#
# Processando 112: A área de resgate deve ser provida de dispositivo de emergência ou intercomunicador.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.77 segundos
#
# Processando 113: A área de resgate deve ter o M.R. sinalizado conforme 5.5.2.2.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.48 segundos
#
# Processando 114: Superfícies de piso com declividade igual ou superior a 5% são consideradas rampas, e devem atender às condições de 6.3.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.92 segundos
#
# Processando 115: Em reformas, quando esgotadas as possibilidades de soluções que atendam integralmente ao item 6.6.2.1, podem ser utilizadas inclinações superiores a 8,33% (1:12) e até 12,5% (1:8), em segmentos retos, e devem atender os desníveis máximos por segmento e número de segmentos deste item.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. SOMENTE do Texto N1.', 'selecao': 'Parte mais específica da aplicabilidade. SOMENTE extraído após a remoção de aplicabilidade, sem repetir o requisito. NÃO pode conter verbos, ações ou condições. Se não houver seleção, retorna "" (string vazia).', 'execao': 'Casos que NÃO precisam seguir a regra. SOMENTE extraído após a remoção de aplicabilidade e seleção. Se um elemento for uma exceção, ele não pode estar em outro campo. Se não houver exceção, retorna "" (string vazia).', 'requisito': 'O que deve ser feito (ação ou condição). SOMENTE extraído após a remoção de aplicabilidade, seleção e exceção. NÃO pode conter informações da aplicabilidade, seleção ou exceção. O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 2.40 segundos
#
# Processando 116: Rampas com declividade maior do que 8,33% (1:12) e até 10% (1:10) devem ter desnível máximo de 0,20 m por segmento, com no máximo 4 segmentos.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.63 segundos
#
# Processando 117: Rampas com declividade maior do que 10% (1:10) e até 12,5% (1:8) devem ter desnível máximo de 0,075 m por segmento, com no máximo 1 segmento.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.64 segundos
#
# Processando 118: A inclinação transversal de rampas internas não pode exceder 2%.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '', 'execao': '', 'requisito': '"A inclinação transversal de rampas internas não pode exceder 2%."'}
# Tempo gasto: 0.56 segundos
#
# Processando 119: A inclinação transversal de rampas externas não pode exceder 3%.
# Retorno do modelo:
# {'aplicabilidade': 'A regra se aplica a rampas externas.', 'selecao': 'Parte mais específica da aplicação à regra sobre rampas externas.', 'execao': 'Casos em que não é necessário seguir esta regra.', 'requisito': 'A inclinação transversal de rampas externas não pode exceder 3%.'}
# Tempo gasto: 0.81 segundos
#
# Processando 120: Toda rampa deve possuir corrimão de duas alturas em cada lado.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.45 segundos
#
# Processando 121: A projeção dos corrimãos pode incidir dentro da largura mínima admissível da rampa em até 10 cm de cada lado, exceto quando a largura da rampa for inferior a 1,20 m (casos previstos em 6.6.2.7).
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.44 segundos
#
# Processando 122: Devem ser previstos patamares no início e término das rampas.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '"Parte mais específica da aplicabilidade."', 'execao': '"Casos que NÃO precisam seguir a regra."', 'requisito': '"Devem ser previstos patamares no início e término das rampas."'}
# Tempo gasto: 0.76 segundos
#
# Processando 123: Devem ser previstos patamares intermediários (entre segmentos) nas rampas.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraída primeiro, antes de outros elementos.', 'selecao': '- Parte mais específica da aplicabilidade. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra. - Se um elemento for uma exceção, ele não pode estar em outro campo. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção.', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - NÃO pode conter informações da aplicabilidade, seleção ou exceção.'}
# Tempo gasto: 1.88 segundos
#
# Processando 124: Devem ser previstos patamares quando houver mudança de direção nas rampas.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.40 segundos
#
# Processando 125: Os patamares de início, término e intermediários devem ter dimensão longitudinal mínima de 1,20 m.
# Retorno do modelo:
# {'aplicabilidade': '- "onde ou quando a regra se aplica" "Parte mais específica da aplicabilidade" - "deve ser um subconjunto da aplicabilidade, sem repetir o requisito" "Casos que NÃO precisam seguir a regra" - "Se um elemento for uma exceção, ele não pode estar em outro campo." "O que deve ser feito (ação ou condição)" - "NÃO pode conter informações da aplicabilidade, seleção ou exceção." - "Deve começar com um verbo e expressar uma ação clara."', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 1.57 segundos
#
# Processando 126: Os patamares situados em mudança de direção devem ter dimensões iguais à largura da rampa.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraído primeiro, antes de outros elementos. - Extraído SOMENTE do TEXTO N1.', 'selecao': '- Parte mais específica da aplicabilidade. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade.', 'execao': '- Casos que NÃO precisam seguir a regra. - Se um elemento for uma exceção, ele não pode estar em outro campo. - O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - NÃO pode conter informações da aplicabilidade, seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação clara.', 'requisito': ''}
# Tempo gasto: 2.02 segundos
#
# Processando 127: A inclinação transversal de patamares em rampas internas não pode exceder 2%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '- "Onde ou quando a regra se aplica." - Deve ser extraído primeiro, antes de outros elementos. - Extraído APENAS do TEXTO N1. - "Parte mais específica da aplicabilidade." - Extraído APENAS do TEXTO N1, após a remoção de aplicabilidade. - Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. - "Casos que NÃO precisam seguir a regra." - Extraído APENAS do TEXTO N1, após a remoção de aplicabilidade e seleção. - Se um elemento for uma exceção, ele não pode estar em outro campo. - “O que deve ser feito (ação ou condição).” - Extraído APENAS do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - Não pode conter informações da aplicabilidade, seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 9.58 segundos
#
# Processando 128: A inclinação transversal de patamares em rampas externas não pode exceder 3%.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': '', 'execao': 'Casos que NÃO precisam seguir a regra.', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.71 segundos
#
# Processando 129: Uma sequência de três degraus ou mais deve ser tratada como escada.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade. - Deve ser um subconjunto da aplicação, sem repetir o requisito.', 'execao': '- Casos que NÃO precisam seguir a regra.', 'requisito': '- O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.89 segundos
#
# Processando 130: A largura das escadas deve ser estabelecida de acordo com o fluxo de pessoas, conforme ABNT NBR 9077.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.12 segundos
#
# Processando 131: A largura mínima para escadas em rotas acessíveis é de 1,20 m.
# Retorno do modelo:
# {'aplicabilidade': '"Onde a largura mínima para escadas em rotas acessíveis se aplica."', 'selecao': '""', 'execao': '""', 'requisito': '"A largura mínima para escadas em rotas acessíveis é de 1,20 m."'}
# Tempo gasto: 0.66 segundos
#
# Processando 132: Deve dispor de guia de balizamento conforme 6.6.3.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica.', 'selecao': '- Parte mais específica da aplicabilidade.', 'execao': '""', 'requisito': '- O que deve ser feito (ação ou condição). - Dispor de guia de balizamento.'}
# Tempo gasto: 0.69 segundos
#
# Processando 133: A inclinação transversal dos degraus em escadas internas não pode exceder 1%.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '""', 'execao': '""', 'requisito': '"A inclinação transversal dos degraus em escadas internas não pode exceder 1%."'}
# Tempo gasto: 0.61 segundos
#
# Processando 134: A inclinação transversal dos degraus em escadas externas não pode exceder 2%.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica. NÃO pode conter verbos, ações ou condições. Parte mais específica da aplicabilidade. Extraído apenas do TEXTO N1, após a remoção de aplicação. Não pode conter verbos, ações ou condições. Se não houver seleção, retorne "" (string vazia). Casos que NÃO precisam seguir a regra. Extraído apenas do TEXTO N1, após a remoção de aplicação e seleção. Se um elemento for uma exceção, ele não pode estar em outro campo. Se não houver, retorne "" (string vazia).', 'selecao': '', 'execao': '', 'requisito': 'O que deve ser feito (ação ou condição). Extraído apenas do TEXTO N1, após a remoção de aplicação, seleção e exceção. Não pode conter informações da aplicabilidade, seleção ou exceção. O requisito deve começar com um verbo e expressar uma ação ou condição clara.'}
# Tempo gasto: 2.57 segundos
#
# Processando 135: A inclinação transversal de patamares em escadas internas não pode exceder 1%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.29 segundos
#
# Processando 136: A inclinação transversal de patamares em escadas externas não pode exceder 2%.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.44 segundos
#
# Processando 137: O dimensionamento dos corrimãos deve atender ao descrito em 4.6.5.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.21 segundos
#
# Processando 138: Os corrimãos laterais devem ser contínuos, sem interrupção nos patamares das escadas e rampas.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.40 segundos
#
# Processando 139: Os corrimãos laterais devem prolongar-se paralelamente ao patamar, pelo menos por 0,30 m nas extremidades, sem interferir com áreas de circulação ou prejudicar a vazão.
# Retorno do modelo:
# {'aplicabilidade': '"Os corrimãos laterais devem"', 'selecao': '"paralelamente ao patamar, pelo menos por 0,30 m nas extremidades"', 'execao': '"sem interferir com áreas de circulação ou prejudicar a vazão."', 'requisito': '"prolongado"'}
# Tempo gasto: 1.01 segundos
#
# Processando 140: Em edificações existentes, onde for impraticável promover o prolongamento do corrimão no sentido do caminhamento, este pode ser feito ao longo da área de circulação ou fixado na parede adjacente.
# Retorno do modelo:
# {'aplicabilidade': 'Em edificações existentes', 'selecao': 'onde é impraticável promover o prolongamento do corrimão no sentido do caminhamento', 'execao': '"onde for impraticável promover"', 'requisito': 'este pode ser feito ao longo da área de circulação ou fixado na parede adjacente'}
# Tempo gasto: 0.80 segundos
#
# Processando 141: Os corrimãos intermediários devem ser interrompidos quando o comprimento do patamar for superior a 1,40 m, garantindo o espaçamento mínimo de 0,80 m entre o término de um segmento e o início do seguinte.
# Retorno do modelo:
# {'aplicabilidade': '"Os corrimãos intermediários"', 'selecao': '""', 'execao': '""', 'requisito': '"garantir o espaçamento mínimo de 0,80 m"'}
# Tempo gasto: 1.15 segundos
#
# Processando 142: Quando não houver paredes laterais, as rampas ou escadas devem incorporar elementos de segurança como guia de balizamento e guarda-corpo, e devem respeitar os demais itens de segurança desta Norma, tais como dimensionamento, corrimãos e sinalização.
# Retorno do modelo:
# {'aplicabilidade': '"Quando não houver paredes laterais"', 'selecao': '', 'execao': '', 'requisito': '"devem incorporar elementos de segurança"'}
# Tempo gasto: 1.14 segundos
#
# Processando 143: Em espaços com portas em sequência, deve ser garantido um espaço mínimo equivalente a um círculo de 1,50 m de diâmetro, livre de quaisquer obstáculos, inclusive da área de varredura das portas simultaneamente.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '"não há seleção fornecida no texto fornecido"', 'execao': '"sem exceções fornidas na entrada de texto"', 'requisito': '"deve ser garantido um espaço mínimo equivalente a um círculo de 1,50 m de diâmetro livre de quaisquer obstáculos inclusive da área de varredura das portas simultaneamente."'}
# Tempo gasto: 1.09 segundos
#
# Processando 144: Em espaços com portas em sequência, deve ser garantido um espaço mínimo de 0,60m ao lado da maçaneta de cada porta.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraído primeiro, antes de outros elementos.', 'selecao': '- Parte mais específica da aplicabilidade. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade. - Deve ser um subconjunto da aplicabilidade sem repetir o requisito. - Se não houver seleção, retornar `""` (string vazia).', 'execao': '- Casos que NÃO precisam seguir a regra. - Extraído SOMENTE do TEXTO N1 após a remoção de aplicabilidade e seleção. - Se um elemento for uma exceção ele não pode estar em outro campo. - Se não houver, retornar `""` (string vazia).', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1 após a remoção de aplicabilidade seleção e exceção. - Não pode conter informações da aplicabilidade seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 2.58 segundos
#
# Processando 145: No deslocamento lateral, no lado da circulação oposto à abertura da porta, deve ser garantido 0,60 m de espaço livre de cada um dos lados da porta, e largura mínima de circulação de 1,20 m.
# Retorno do modelo:
# {'aplicabilidade': '- "No deslocamento lateral, no lado da circulação oposto à abertura da porta," - "deve ser garantido 0,60 m de espaço livre de cada um dos lados da porta,"', 'selecao': '- largura mínima de circulação de 1,20 m', 'execao': '""', 'requisito': ''}
# Tempo gasto: 1.08 segundos
#
# Processando 146: No deslocamento lateral, no lado da circulação em que a porta abre, deve ser garantido 0,90 m de espaço livre do lado contíguo à maçaneta, e largura mínima da circulação de 1,50 m.
# Retorno do modelo:
# {'aplicabilidade': 'Lado da circulação com porta aberta', 'selecao': '0,90 metros de espaço livre do lado contíguo à maçaneta e largura mínima da circulação de 1,50 metros', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.54 segundos
#
# Processando 147: Na impraticabilidade da existência destes espaços livres, deve-se garantir equipamento de automação da abertura e fechamento das portas através de botoeira ou sensor, conforme 6.11.2.9 e 6.11.2.10.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.72 segundos
#
# Processando 148: As portas instaladas em locais de prática esportiva, quando abertas, devem ter um vão livre, de no mínimo 1,00 m de largura e 2,10 m de altura.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 2.94 segundos
#
# Processando 149: As maçanetas das portas devem ser do tipo alavanca, instaladas a uma altura entre 0,80 m e 1,10 m.
# Retorno do modelo:
# {'aplicabilidade': 'Deve ser extraída primeiro, antes de outros elementos.', 'selecao': 'Se não houver seleção, retornar `""` (string vazia).', 'execao': 'Se não houver exceção, retornar `""` (string vazia).', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.78 segundos
#
# Processando 150: As portas do tipo vaivém devem ter visor com largura mínima de 0,20 m, tendo sua face inferior situada entre 0,40 m e 0,90 m do piso, e a face superior no mínimo a 1,50 m do piso.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.67 segundos
#
# Processando 151: O visor deve estar localizado no mínimo entre o eixo vertical central da porta e o lado oposto às dobradiças da porta.
# Retorno do modelo:
# {'aplicabilidade': 'Onde ou quando a regra se aplica.', 'selecao': 'Parte mais específica da aplicabilidade (não pode conter verbos, ações ou condições).', 'execao': 'Casos que NÃO precisam seguir a regra (se não houver, retornar `""` (string vazia)).', 'requisito': 'O que deve ser feito (ação ou condição).'}
# Tempo gasto: 0.94 segundos
#
# Processando 152: Quando as portas forem acionadas por sensores ópticos, estes devem estar ajustados para detectar pessoas de baixa estatura, crianças e usuários de cadeiras de rodas.
# Retorno do modelo:
# {'aplicabilidade': 'Quando as portas são acionadas por sensores ópticos.', 'selecao': 'detectar pessoas com baixa estatura, crianças e usuários de cadeiras de rodas.', 'execao': '"" (string vazia).', 'requisito': 'estes devem estar ajustados.'}
# Tempo gasto: 0.73 segundos
#
# Processando 153: Quando as portas forem acionadas por sensores ópticos, deve ser previsto dispositivo de segurança que impeça o fechamento da porta sobre a pessoa.
# Retorno do modelo:
# {'aplicabilidade': '- Onde ou quando a regra se aplica. - Deve ser extraída primeiro, antes de outros elementos. - Extraído SOMENTE do TEXTO N1. - NÃO pode conter verbos, ações ou condições.', 'selecao': '- Parte mais específica da aplicabilidade. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade. - Deve ser um subconjunto da aplicabilidade, sem repetir o requisito. - NÃO pode conter verbos, ações ou condições.', 'execao': '- Casos que NÃO precisam seguir a regra. - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade e seleção. - Se um elemento for uma exceção, ele não pode estar em outro campo. - Se não houver, retornar `""` (string vazia).', 'requisito': '- O que deve ser feito (ação ou condição). - Extraído SOMENTE do TEXTO N1, após a remoção de aplicabilidade, seleção e exceção. - NÃO pode conter informações da aplicabilidade, seleção ou exceção. - O requisito deve começar com um verbo e expressar uma ação clara.'}
# Tempo gasto: 2.94 segundos
#
# Processando 154: a) a sinalização deve ser em faixa contínua ou elementos gráficos, com no mínimo 50 mm de espessura, instalada a uma altura entre 0,90 m e 1,00 m em relação ao piso acabado.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.57 segundos
#
# Processando 155: b) nas portas das paredes envidraçadas que façam parte de rotas acessíveis, deve haver faixa de sinalização visual emoldurando-as, com dimensão mínima de 50 mm de largura.
# Retorno do modelo:
# {'aplicabilidade': 'onde a regra se aplica nas portas das paredes envidraçadas que fazem parte da acessibilidade NÃO pode conter verbos, ações ou condições Se não houver aplicabilidade, retornar `""`', 'selecao': 'parte mais específica da aplicação em relação às portas das paredes envidraçadas que fazem parte de rotas acessíveis NÃO pode conter verbos, ações ou condições Se não houver seleção, retornar `""`', 'execao': 'casos que NÃO precisam seguir a regra no contexto das portas das paredes envidraçadas que fazem parte da acessibilidade NÃO pode ser uma exceção para outros requisitos Se não houver exceções, retornar `""`', 'requisito': 'A ação ou condição de colocar faixa de sinalização visual emoldurando as portas das paredes envidraçadas que fazem parte da acessibilidade com dimensão mínima de 50 mm de largura NÃO pode conter aplicabilidade, seleção ou exceções Retorne somente a resposta'}
# Tempo gasto: 2.69 segundos
#
# Processando 156: c) recomenda-se que a faixa tenha duas cores com o mínimo de 30 pontos de contraste de LRV entre elas;
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.34 segundos
#
# Processando 157: d) recomenda-se a aplicação de mais duas faixas contínuas com no mínimo 50 mm de altura, uma a ser instalada entre 1,30 m e 1,40 m, e outra entre 0,10 m e 0,30 m, em relação ao piso acabado.
# Retorno do modelo:
# {'aplicabilidade': '"Onde ou quando a regra se aplica."', 'selecao': '"Parte mais específica da aplicabilidade."', 'execao': '"Casos que NÃO precisam seguir a regra."', 'requisito': '"O que deve ser feito (ação ou condição)."'}
# Tempo gasto: 0.70 segundos
#
# Processando 158: As vagas para estacionamento de veículos que conduzam ou sejam conduzidos por idosos devem ser posicionadas próximas das entradas, garantindo o menor percurso de deslocamento.
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': '- "posicionado próximo às entradas."'}
# Tempo gasto: 0.32 segundos
#
# Processando 159: Desníveis superiores a 5 mm até 20 mm devem possuir inclinação máxima de 1:2 (50 %).
# Retorno do modelo:
# {'aplicabilidade': '', 'selecao': '', 'execao': '', 'requisito': ''}
# Tempo gasto: 0.89 segundos
#
# Processamento concluído. Tempo total: 166.63 segundos.
# Resultado salvo em ../databases/generate_n2_dolphin.json
